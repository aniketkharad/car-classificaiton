# %% [markdown]
# Classification of Cars using Feed Forward Network(Perceptron)

# %% [markdown]
# Data Preprocessing Part

# %% [raw]
# Importing the required Libraries

# %%
import os
import glob
import pickle
import random
import numpy as np
import cv2
from datetime import datetime

# %% [raw]
# os.chdir('../DEEP LEARNING1/Dataset/')
# Getting the file from Different Directories
# os.chdir('../')

# %%
directories = [name for name in glob.glob('Dataset/*') if os.path.isdir(name)]
directories
# Out:
# ['Dataset\\AM General Hummer SUV 2000',
#  'Dataset\\Aston Martin V8 Vantage Convertible 2012',
#  'Dataset\\Aston Martin V8 Vantage Coupe 2012',
#  'Dataset\\Aston Martin Virage Convertible 2012',
#  'Dataset\\Aston Martin Virage Coupe 2012',
#  'Dataset\\Bentley Arnage Sedan 2009',
#  'Dataset\\Bentley Continental Flying Spur Sedan 2007',
#  'Dataset\\Bentley Continental GT Coupe 2007',
#  'Dataset\\Bentley Continental GT Coupe 2012',
#  'Dataset\\Bentley Continental Supersports Conv. Convertible 2012',
#  'Dataset\\Bentley Mulsanne Sedan 2011',
#  'Dataset\\Bugatti Veyron 16.4 Convertible 2009',
#  'Dataset\\Bugatti Veyron 16.4 Coupe 2009',
#  'Dataset\\Ferrari 458 Italia Convertible 2012',
#  'Dataset\\Ferrari 458 Italia Coupe 2012',
#  'Dataset\\Ferrari California Convertible 2012',
#  'Dataset\\Ferrari FF Coupe 2012',
#  'Dataset\\Rolls-Royce Ghost Sedan 2012',
#  'Dataset\\Rolls-Royce Phantom Drophead Coupe Convertible 2012',
#  'Dataset\\Rolls-Royce Phantom Sedan 2012']

# %%
len(directories)
# Out:
# 20

# %% [raw]
# Preparing the final target class used in the Algorithm

# %%
classes = []
for directory in directories:
    classes.append(directory.split('\\')[1])
classes
# Out:
# ['AM General Hummer SUV 2000',
#  'Aston Martin V8 Vantage Convertible 2012',
#  'Aston Martin V8 Vantage Coupe 2012',
#  'Aston Martin Virage Convertible 2012',
#  'Aston Martin Virage Coupe 2012',
#  'Bentley Arnage Sedan 2009',
#  'Bentley Continental Flying Spur Sedan 2007',
#  'Bentley Continental GT Coupe 2007',
#  'Bentley Continental GT Coupe 2012',
#  'Bentley Continental Supersports Conv. Convertible 2012',
#  'Bentley Mulsanne Sedan 2011',
#  'Bugatti Veyron 16.4 Convertible 2009',
#  'Bugatti Veyron 16.4 Coupe 2009',
#  'Ferrari 458 Italia Convertible 2012',
#  'Ferrari 458 Italia Coupe 2012',
#  'Ferrari California Convertible 2012',
#  'Ferrari FF Coupe 2012',
#  'Rolls-Royce Ghost Sedan 2012',
#  'Rolls-Royce Phantom Drophead Coupe Convertible 2012',
#  'Rolls-Royce Phantom Sedan 2012']

# %%
len(classes)
# Out:
# 20

# %% [raw]
# The final feature dataset should be in the form of nested tuples,dictionaries,lists
# The Format specified is
# [(class,{actual_pathname:'absolute path to png file'})]

# %%
feature_data = []
for directory in directories:
    paths = glob.glob(directory+'/*.jpg')
    current_class = directory.split('\\')[1]
    for path in paths:
        feature_dictionary = {}
        feature_dictionary['path'] = path
        feature_data.append((current_class,feature_dictionary))

len(feature_data)
# Out:
# 1575

# %%
feature_data
# Out:
# [('AM General Hummer SUV 2000',
#   {'path': 'Dataset\\AM General Hummer SUV 2000\\
jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01184.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01249.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01293.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01381.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01484.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01703.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01708.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01788.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\01818.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02025.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02126.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02309.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02392.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02427.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02520.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02643.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02681.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02735.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02768.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02784.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02824.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02837.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02889.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02933.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02963.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\02970.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03112.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03278.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03330.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03479.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03502.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03619.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03660.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03693.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03751.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03763.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\03881.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04043.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04110.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04120.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04210.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04401.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04609.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04741.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04787.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04807.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\04822.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\05016.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\05049.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\05134.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\05493.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\05556.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\05563.jpg'}),
#  ('Bugatti Veyron 16.4 Coupe 2009',
#   {'path': 'Dataset\\Bugatti Veyron 16.4 Coupe 2009\\05737.jpg'}),
#  ...]

# %% [raw]
# We Extract data from Different Directories and then To feed it to the Neural Network Shuffle it
# so than the Network is not biased and manual mappings cannot be done

# %%
random.shuffle(feature_data)

# %% [raw]
# Saving Data for fast access
# AND
# Retrievng the Stored Data from the DB

# %%
with open('feature_data.pkl','wb') as f:
    pickle.dump(feature_data,f)
with open('classes.pkl','wb') as f:
    pickle.dump(classes,f)
    
with open('feature_data.pkl','rb') as f:
    feature_data = pickle.load(f)
with open('classes.pkl','rb') as f:
    classes = pickle.load(f)

# %% [markdown]
# Designing the Network

# %% [raw]
# Step 1 Initialise Weights and Biases to small random values and set the Learning Rate
#
# Constants
# BIAS                      format(random.randint(2500, 7500)/10000, '.4f')# Dummy Feature for use in setting constant factor in Training.
# TRAIN_TEST_RATIO          Default Ratio of data to be used in Training vs. Testing.
# ITERATIONS                Number of Training Iterations.(Epochs)
# LR                        Set learning rate(Alpha)

# %% [markdown]
# Training Algorithm Begins

# %%
bias = 1
Train_Test_Ratio = 0.8
Iterations = 30
lr = 0.01

# %% [raw]
# Defining Differernt Activation Functions Here Choice of Activation Functions?

# %%
def sigmoid(x):
    return (1/1+np.exp(-x))

def ReLu(x):
    return max(0,x)

# %% [raw]
# Defining the Perceptron Class
# A MultiClass Perceptron Model for training of Data,Predicting Analysing Features etc
# Splitting Feature Data into Training and Testing Set For The Second step i;e training pair s:t
# Initialising the Weight Vectors in the Form of a Dictionary with BIAS terms
# Done with Step1 now train the network
#
# #####
# Train the Multi-Class Perceptron algorithm using the following method:
#
#         Step2 : For each training pair s:t, the data (formatted as a feature vector) is read in, and the dot
#                 product is taken with each unique weight vector (which are all initially set to 0).
#
#         Step3 : Calculate the net I/P Yin = bias + summation(x*wts).
#
#         Step4 : Pass it to the Activations Functions.
#
#         Step5 : The class that
#         yields the highest product is the class to which the data belongs. In the case this class is the
#         correct value (matches with the actual category to which the data belongs), nothing happens, and the
#         next data point is read in. However, in the case that the predicted value is wrong, the weight vectors a
#         re corrected as follows: The feature vector is subtracted from the predicted weight vector, and added to
#         the actual (correct) weight vector. This makes sense, as we want to reject the wrong answer, and accept
#         the correct one.

# %% [raw]
# FOR FUNCTION TRAIN:
#
# A MultiClass Perceptron Model for training of Data,Predicting Analysing Features etc
# Splitting Feature Data into Training and Testing Set For The Second step i;e training pair s:t
# Initialising the Weight Vectors in the Form of a Dictionary with BIAS terms
# Done with Step1 now train the network
# For Number of Epochs
# 	Obtaininig the Image and preprocessing it
# 	Dimension Required for Resizing the Data
# 	Normalising the Image between 0 and 1
# 	Appending Extra Bias for each Input
# 	Initialise ARG_MAX we perform our activations with that
#
# 	We Make MultiClass Decision Rule Based on the above conditions
#
# 	Updation of Weights And Biases
#         that is y!=t Update weights and biases
#         If y!=t we reduce its probability
#
# FOR FUNCTION PREDICT:
#
# To check whether our model can generalise well as it has been trained so it has to learn well to Generalize well
# Normalising the Image between 0 and 1
# We Make MultiClass Decision Rule Based on the above conditions
#
# FOR CALCULATION OF ACCURACY:
#
# Calculates the accuracy of the classifier by running algorithm against test set and comparing the output to the actual categorization.
#
# SELECTING RANDOM PICTURE:
#
# Reading Individual Image For Classification
# Rreading the Image Using Open CV
# Normalising the Image between 0 and 1

# %%
class MultiClassPerceptron:
    
    accuracy = 0
    def __init__(self,classes,feature_data,hidden,train_test_ratio=Train_Test_Ratio,iterations=Iterations):
        self.classes = classes
        self.hidden = hidden
        self.feature_data = feature_data
        self.ratio = train_test_ratio
        self.iterations = iterations
        
        random.shuffle(self.feature_data)
        self.train_set = self.feature_data[:int(len(self.feature_data)*self.ratio)]
        self.test_set = self.feature_data[int(len(self.feature_data)*self.ratio):]
        
        self.weight_vectors = {c:np.array([0.0 for _ in range(9601)]) for c in self.hidden}
        self.weight_hidd_out = {p:np.array([0.0 for _ in range(len(self.hidden))]) for p in self.classes}
        
        
    def train(self):

                
        #####
        
        for _ in range(self.iterations):
            i = 0
            for category,feature_dictionary in self.train_set:
                i+=1
                fract = i / len(self.train_set)
                print('{:>2.2%}'.format(fract), end="\r")

                image = cv2.imread(feature_dictionary['path'])
                dim = (120,80)
                resized_image = cv2.resize(image,dim,cv2.INTER_AREA)

                input_array = []
                input_array = [np.mean(resized_image[i][j]/255) for i in range(resized_image.shape[0])
                              for j in range(resized_image.shape[1])]
                input_array.append(bias)
                input_vector = np.array(input_array)
                
                arg_max,predicted_class = 0,self.classes[0]
                
                input_array_hidden = []
                
                for index in self.hidden:
                    current_activation = np.dot(input_vector,self.weight_vectors[index])
                    current_activation = ReLu(current_activation)
                    input_array_hidden.append(current_activation)
                    #if current_activation >= arg_max:
                        #arg_max,predicted_class = current_activation,index
                    
                for index in self.classes:
                    current_activation = np.dot(input_array_hidden,self.weight_hidd_out[index])
                    if current_activation >= arg_max:
                        arg_max,predicted_class = current_activation,index
                        
                if not(category == predicted_class):
                    for index in self.hidden:
                        target = int(category[-1])
                        self.weight_vectors[int(index)] += [weight*lr*target for weight in input_vector]
#                         self.weight_vectors[predicted_class] -= [weight*lr for weight in input_vector]

            print(str(datetime.now().strftime("%H:%M:%S")) + '\tCompleted epoch:    {}'.format(_+1), end="")
            self.calculate_accuracy()
            
                        
         
    def predict(self,feature_dictionary):
        
        img = cv2.imread(feature_dictionary['path'])
        dim = (120,80)
        resized_image = cv2.resize(img,dim,cv2.INTER_AREA)
        
        input_array = []
        input_array = [np.mean(resized_image[i][j]/255) for i in range(resized_image.shape[0])
                      for j in range(resized_image.shape[1])]
        
        
        input_array.append(bias)
        feature_vector = np.array(input_array)
        
        arg_max,predicted_class = 0,self.classes[0]
                
        input_array_hidden = []

        for index in self.hidden:
            current_activation = np.dot(feature_vector,self.weight_vectors[index])
            current_activation = ReLu(current_activation)
                    
            input_array_hidden.append(current_activation)
                
        for index in self.classes:
            current_activation = np.dot(input_array_hidden,self.weight_hidd_out[index])
            current_activation = ReLu(current_activation)
            if current_activation >= arg_max:
                arg_max,predicted_class = current_activation,index
                
        return predicted_class
    
    
    def test_random_data(self):
        item = random.choice(self.test_set)
        print("Actual Class :" + item[0])
        pred_class = self.predict(item[1])
        print("\tPredicted Class :" + pred_class)
        
        
    def calculate_accuracy(self):
        
        correct,incorrect = 0,0
        random.shuffle(self.feature_data)
        self.test_set = self.feature_data[int(len(self.feature_data)*self.ratio):]
        for feature_dictionary in self.test_set:
            actual_class = feature_dictionary[0]
            predicted_class = self.predict(feature_dictionary[1])
            
            if actual_class == predicted_class:
                correct += 1
            else:
                incorrect += 1
                
#         print("ACCURACY")
        print("Accuracy of FF Model is ",format(((correct * 1.0) / ((correct + incorrect) * 1.0)*100), '.2f'))
        
    
    def select_random_picture(self):
        
        s = glob.glob(os.getcwd() + '\\Testing_Sample/*')
        
        img = cv2.imread(s[0])
        dim = (120,80)
        resized_image = cv2.resize(img,dim,cv2.INTER_AREA)
        
        input_array = []
        input_array = [np.mean(resized_image[i][j]/255) for i in range(resized_image.shape[0])
                      for j in range(resized_image.shape[1])]
        
        
        input_array.append(bias)
        feature_vector = np.array(input_array)
        
        
        arg_max,predicted_class = 0,self.classes[0]
    
        for index in self.classes:
            current_activation = np.dot(feature_vector,self.weight_vectors[index])
            if current_activation >= arg_max:
                arg_max,predicted_class = current_activation,index
                
        print("The Predicted Class for the Sample Image is")
        print(predicted_class)

# %% [raw]
# The MAin function driver function

# %%
if __name__ == "__main__":
    hidden_neuron = [i for i in range(96)]
    classifier = MultiClassPerceptron(classes,feature_data,hidden_neuron)
    classifier.train()
#     classifier.calculate_accuracy()
#     classifier.test_random_data()
# Out:
# 18:17:14	Completed epoch:    1Accuracy of FF Model is  5.08
# 18:33:32	Completed epoch:    2Accuracy of FF Model is  4.76
# 18:49:54	Completed epoch:    3Accuracy of FF Model is  6.35
# 19:06:23	Completed epoch:    4Accuracy of FF Model is  7.62
# 19:23:11	Completed epoch:    5Accuracy of FF Model is  5.08
# 19:39:51	Completed epoch:    6Accuracy of FF Model is  6.98
# 19:56:09	Completed epoch:    7Accuracy of FF Model is  6.98
# 20:12:27	Completed epoch:    8Accuracy of FF Model is  6.35
# 20:29:45	Completed epoch:    9Accuracy of FF Model is  4.76
# 20:47:33	Completed epoch:    10Accuracy of FF Model is  8.25
# 21:04:36	Completed epoch:    11Accuracy of FF Model is  7.94
# 21:20:54	Completed epoch:    12Accuracy of FF Model is  7.30
# 21:37:15	Completed epoch:    13Accuracy of FF Model is  4.13
# 21:53:35	Completed epoch:    14Accuracy of FF Model is  5.08
# 22:10:18	Completed epoch:    15Accuracy of FF Model is  5.40
# 22:26:35	Completed epoch:    16Accuracy of FF Model is  4.76
# 22:42:56	Completed epoch:    17Accuracy of FF Model is  6.98
# 22:59:18	Completed epoch:    18Accuracy of FF Model is  5.08
# 23:15:39	Completed epoch:    19Accuracy of FF Model is  5.71
# 23:31:59	Completed epoch:    20Accuracy of FF Model is  6.98
# 23:48:40	Completed epoch:    21Accuracy of FF Model is  5.40
# 00:04:53	Completed epoch:    22Accuracy of FF Model is  8.25
# 00:21:05	Completed epoch:    23Accuracy of FF Model is  8.25
# 00:37:17	Completed epoch:    24Accuracy of FF Model is  5.71
# 00:53:32	Completed epoch:    25Accuracy of FF Model is  5.40
# 01:09:47	Completed epoch:    26Accuracy of FF Model is  6.35
# 01:26:01	Completed epoch:    27Accuracy of FF Model is  5.40
# 01:42:14	Completed epoch:    28Accuracy of FF Model is  4.13
# 01:58:28	Completed epoch:    29Accuracy of FF Model is  5.08
# 02:14:42	Completed epoch:    30Accuracy of FF Model is  6.35

# %%
for _ in range(20):
    classifier.test_random_data()
    print('\n')
# Out:
# Actual Class :Bugatti Veyron 16.4 Coupe 2009
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bugatti Veyron 16.4 Convertible 2009
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Continental GT Coupe 2007
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Continental Flying Spur Sedan 2007
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :AM General Hummer SUV 2000
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Rolls-Royce Ghost Sedan 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Continental Supersports Conv. Convertible 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Aston Martin Virage Coupe 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Ferrari FF Coupe 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Continental Supersports Conv. Convertible 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Arnage Sedan 2009
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Arnage Sedan 2009
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Rolls-Royce Ghost Sedan 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Rolls-Royce Phantom Sedan 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Continental GT Coupe 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Aston Martin Virage Convertible 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Bentley Continental Flying Spur Sedan 2007
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Aston Martin Virage Coupe 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Ferrari 458 Italia Convertible 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012
#
#
# Actual Class :Rolls-Royce Phantom Drophead Coupe Convertible 2012
# 	Predicted Class :Rolls-Royce Phantom Sedan 2012

# %%
classifier.select_random_picture()
# Out:
# ------------------------------------------------------------------
# KeyError                         Traceback (most recent call last)
# <ipython-input-15-dea08b65dcc6> in <module>
# ----> 1 classifier.select_random_picture()
#
# <ipython-input-12-f49b26327ae2> in select_random_picture(self)
#     144
#     145         for index in self.classes:
# --> 146             current_activation = np.dot(feature_vector,self.weight_vectors[index])
#     147             if current_activation >= arg_max:
#     148                 arg_max,predicted_class = current_activation,index
#
# KeyError: 'AM General Hummer SUV 2000'
